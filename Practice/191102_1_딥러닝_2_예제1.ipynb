# %%
import numpy as np

# %%
def numerical_derivative(f, x):
    delta_x = 1e-4 # 0.0001
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    
    while not it.finished:
        idx = it.multi_index        
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + delta_x
        fx1 = f(x) # f(x+delta_x)
        
        x[idx] = tmp_val - delta_x 
        fx2 = f(x) # f(x-delta_x)
        grad[idx] = (fx1 - fx2) / (2*delta_x)
        
        x[idx] = tmp_val 
        it.iternext()   
        
    return grad

def sigmoid(x):
    return 1 / (1+np.exp(-x))

# %%
input_data1 = np.array([1, 2])
target_data1 = np.array([1])

# %%
input_nodes = 2
hidden_nodes = 3
output_nodes = 1

# %%
W2 = np.random.rand(input_nodes, hidden_nodes)
W3 = np.random.rand(hidden_nodes, output_nodes)
    
b2 = np.random.rand(hidden_nodes)
b3= np.random.rand(output_nodes)

print("W2 = ", W2, ", W2.shape = ", W2.shape)
print("b2 = ", b2, ", b2.shape = ", b2.shape)
print("W3 = ", W3, ", W3.shape = ", W3.shape)
print("b3 = ", b3, ", b3.shape = ", b3.shape)
# Out:
# W2 =  [[0.9748272  0.22817918 0.44782704]
#  [0.29983271 0.46941353 0.19009797]] , W2.shape =  (2, 3)
# b2 =  [0.14061273 0.74637708 0.20698104] , b2.shape =  (3,)
# W3 =  [[0.48832384]
#  [0.09307685]
#  [0.37014902]] , W3.shape =  (3, 1)
# b3 =  [0.33616153] , b3.shape =  (1,)

# %%
def feed_forward(xdata):
    delta = 1e-7   
    print("[feed_forward function]") 
    
    Z2 = np.dot(xdata, W2) + b2    
    print("Z2 = ", Z2)
    
    A2 = sigmoid(Z2)    
    print("A2 = ", A2)
    
    Z3 = np.dot(A2, W3) + b3    
    print("Z3 = ", Z3)
    
    y = A3 = sigmoid(Z3)    
    print("y = ", y, ", A3 = ", A3)
    
    loss = -np.sum( target_data1*np.log(y + delta) + (1-target_data1)*np.log((1 - y)+delta ) )    
    print('current loss val = ', loss)
    
    print("[feed_forward function]\n")
        
    return loss

# %%
loss_val = feed_forward(input_data1)
# Out:
# [feed_forward function]
# Z2 =  [1.74895089 1.91976056 1.07364582]
# A2 =  [0.85182043 0.87211173 0.74528963]
# Z3 =  [1.25414671]
# y =  [0.77801685] , A3 =  [0.77801685]
# current loss val =  0.25100696616487855
# [feed_forward function]

# %%
learning_rate = 1e-1

f = lambda x : feed_forward(input_data1)
print('\n=================================================')
print('initial W2 = ', W2)
print('initial b2 = ', b2)
print('initial W3 = ', W3)
print('initial b3 = ', b3)
print('=================================================\n')

W2 -= learning_rate * numerical_derivative( f, W2 )
b2 -= learning_rate * numerical_derivative( f, b2 )

W3 -= learning_rate * numerical_derivative( f, W3 )
b3 -= learning_rate * numerical_derivative( f, b3 )

print('\n=================================================')
print('updated W2 = ', W2)
print('updated b2 = ', b2)
print('updated W3 = ', W3)
print('updated b3 = ', b3)
print('=================================================\n')
# Out:
# =================================================
# initial W2 =  [[0.98098225 0.22934277 0.45485465]
#  [0.31214281 0.47174071 0.2041532 ]]
# initial b2 =  [0.14368301 0.74693637 0.21048476]
# initial W3 =  [[0.52939583]
#  [0.13519302]
#  [0.40601923]]
# initial b3 =  [0.38269118]
# =================================================
#
# [feed_forward function]
# Z2 =  [1.74905089 1.91976056 1.07364582]
# A2 =  [0.85183305 0.87211173 0.74528963]
# Z3 =  [1.2541534]
# y =  [0.77801801] , A3 =  [0.77801801]
# current loss val =  0.25100548289408864
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74885089 1.91976056 1.07364582]
# A2 =  [0.85180781 0.87211173 0.74528963]
# Z3 =  [1.25414003]
# y =  [0.7780157] , A3 =  [0.7780157]
# current loss val =  0.2510084495477532
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91986056 1.07364582]
# A2 =  [0.85182043 0.87212288 0.74528963]
# Z3 =  [1.25414822]
# y =  [0.77801711] , A3 =  [0.77801711]
# current loss val =  0.251006631461069
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91966056 1.07364582]
# A2 =  [0.85182043 0.87210058 0.74528963]
# Z3 =  [1.25414521]
# y =  [0.77801659] , A3 =  [0.77801659]
# current loss val =  0.2510073008939911
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91976056 1.07374582]
# A2 =  [0.85182043 0.87211173 0.74530861]
# Z3 =  [1.25415442]
# y =  [0.77801818] , A3 =  [0.77801818]
# current loss val =  0.2510052552582762
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91976056 1.07354582]
# A2 =  [0.85182043 0.87211173 0.74527065]
# Z3 =  [1.25413901]
# y =  [0.77801552] , A3 =  [0.77801552]
# current loss val =  0.2510086771656766
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74915089 1.91976056 1.07364582]
# A2 =  [0.85184567 0.87211173 0.74528963]
# Z3 =  [1.25416008]
# y =  [0.77801916] , A3 =  [0.77801916]
# current loss val =  0.25100399973537774
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74875089 1.91976056 1.07364582]
# A2 =  [0.85179518 0.87211173 0.74528963]
# Z3 =  [1.25413335]
# y =  [0.77801454] , A3 =  [0.77801454]
# current loss val =  0.25100993304271746
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91996056 1.07364582]
# A2 =  [0.85182043 0.87213404 0.74528963]
# Z3 =  [1.25414973]
# y =  [0.77801737] , A3 =  [0.77801737]
# current loss val =  0.2510062967825614
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91956056 1.07364582]
# A2 =  [0.85182043 0.87208942 0.74528963]
# Z3 =  [1.2541437]
# y =  [0.77801633] , A3 =  [0.77801633]
# current loss val =  0.25100763564840795
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91976056 1.07384582]
# A2 =  [0.85182043 0.87211173 0.7453276 ]
# Z3 =  [1.25416213]
# y =  [0.77801951] , A3 =  [0.77801951]
# current loss val =  0.25100354444587053
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.74895089 1.91976056 1.07344582]
# A2 =  [0.85182043 0.87211173 0.74525166]
# Z3 =  [1.2541313]
# y =  [0.77801419] , A3 =  [0.77801419]
# current loss val =  0.2510103882606698
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75646753 1.92143414 1.08220059]
# A2 =  [0.85276669 0.87229827 0.7469102 ]
# Z3 =  [1.25533086]
# y =  [0.77822129] , A3 =  [0.77822129]
# current loss val =  0.2507442265568195
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75626753 1.92143414 1.08220059]
# A2 =  [0.85274158 0.87229827 0.7469102 ]
# Z3 =  [1.25531757]
# y =  [0.778219] , A3 =  [0.778219]
# current loss val =  0.2507471750456935
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75636753 1.92153414 1.08220059]
# A2 =  [0.85275413 0.87230941 0.7469102 ]
# Z3 =  [1.25532572]
# y =  [0.77822041] , A3 =  [0.77822041]
# current loss val =  0.2507453667645051
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75636753 1.92133414 1.08220059]
# A2 =  [0.85275413 0.87228713 0.7469102 ]
# Z3 =  [1.25532271]
# y =  [0.77821989] , A3 =  [0.77821989]
# current loss val =  0.25074603475163276
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75636753 1.92143414 1.08230059]
# A2 =  [0.85275413 0.87229827 0.7469291 ]
# Z3 =  [1.25533189]
# y =  [0.77822147] , A3 =  [0.77822147]
# current loss val =  0.25074399858829155
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75636753 1.92143414 1.08210059]
# A2 =  [0.85275413 0.87229827 0.74689129]
# Z3 =  [1.25531654]
# y =  [0.77821882] , A3 =  [0.77821882]
# current loss val =  0.2507474029968115
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.25564308]
# y =  [0.77827518] , A3 =  [0.77827518]
# current loss val =  0.2506749921917201
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.25547249]
# y =  [0.77824574] , A3 =  [0.77824574]
# current loss val =  0.2507128182543891
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.25564502]
# y =  [0.77827551] , A3 =  [0.77827551]
# current loss val =  0.2506745621274726
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.25547055]
# y =  [0.7782454] , A3 =  [0.7782454]
# current loss val =  0.250713248376386
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.25563251]
# y =  [0.77827335] , A3 =  [0.77827335]
# current loss val =  0.2506773359945717
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.25548306]
# y =  [0.77824756] , A3 =  [0.77824756]
# current loss val =  0.25071047415963393
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.30104409]
# y =  [0.78601065] , A3 =  [0.78601065]
# current loss val =  0.2407848113139764
# [feed_forward function]
#
# [feed_forward function]
# Z2 =  [1.75784177 1.92176814 1.08390279]
# A2 =  [0.85293915 0.87233547 0.74723184]
# Z3 =  [1.30084409]
# y =  [0.78597701] , A3 =  [0.78597701]
# current loss val =  0.2408276125428552
# [feed_forward function]
#
#
# =================================================
# updated W2 =  [[0.98246558 0.22967749 0.45656561]
#  [0.31510947 0.47241014 0.20757511]]
# updated b2 =  [0.14515726 0.74727036 0.21218697]
# updated W3 =  [[0.54830887]
#  [0.15453615]
#  [0.42258831]]
# updated b3 =  [0.4040918]
# =================================================
