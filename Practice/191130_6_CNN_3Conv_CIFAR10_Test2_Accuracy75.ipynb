# %%
import numpy as np
import tensorflow as tf
from datetime import datetime

# %%
# helper 함수
def weight_variables(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# convolution layer
def conv_layer(input_, shape):
  W = weight_variables(shape)
  b = bias_variable([shape[3]])
  return tf.nn.relu(conv2d(input_, W) + b)

# fully-connected layer
def full_layer(input_, size):
  in_size = int(input_.get_shape()[1])
  W = weight_variables([in_size, size])
  b = bias_variable([size])
  return tf.matmul(input_, W) + b

# %%
# cifar10 데이터 불러오기
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()

# %%
def cifar10_load():

  (train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()

  # Train - Image
  train_x = train_x.astype('float32') / 255

  # Train - Label(OneHot)
  train_y = tf.keras.utils.to_categorical(train_y, num_classes=10)

  # Test - Image
  test_x = test_x.astype('float32') / 255
      
  # Test - Label(OneHot)
  test_y = tf.keras.utils.to_categorical(test_y, num_classes=10)
      
  return (train_x, train_y), (test_x, test_y)

# %%
MINIBATCH_SIZE = 50

(train_x, train_y), (test_x, test_y) = cifar10_load()

dataset = tf.data.Dataset.from_tensor_slices(({"image": train_x}, train_y))

dataset = dataset.shuffle(100000).repeat().batch(MINIBATCH_SIZE)

iterator = dataset.make_one_shot_iterator()

next_batch = iterator.get_next()
# Out:
# WARNING:tensorflow:From <ipython-input-5-81f0afd831c2>:9: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.

# %%
print("Number of train images: {}".format(len(train_x)))
print("Number of train labels: {}".format(len(train_y)))
print("Number of test images: {}".format(len(test_x)))
print("Number of test labels: {}".format(len(test_y)))
# Out:
# Number of train images: 50000
# Number of train labels: 50000
# Number of test images: 10000
# Number of test labels: 10000

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

matplotlib.rc('font', family='NanumGothic')


def display_cifar(images, size):
  
  n = len(images)
  plt.figure()
  plt.gca().set_axis_off()
  im = np.vstack([np.hstack([images[np.random.choice(n)] for i in range(size)]) for i in range(size)])
  plt.imshow(im)
  plt.show()
      
figsize(15, 7)
display_cifar(train_x, 10)

# %%
(train_x, train_y), (test_x, test_y) = cifar10_load()

dataset = tf.data.Dataset.from_tensor_slices(({"image": train_x}, train_y))
dataset = dataset.shuffle(100000).repeat().batch(MINIBATCH_SIZE)
iterator = dataset.make_one_shot_iterator()
next_batch = iterator.get_next()

# %%
# CNN 모델링
x = tf.placeholder(tf.float32, shape=[None, 32, 32, 3])
y_ = tf.placeholder(tf.float32, shape=[None, 10])
keep_prob = tf.placeholder(tf.float32)

conv1 = conv_layer(x, shape=[5, 5, 3, 32])
conv1_pool = max_pool_2x2(conv1)

conv2 = conv_layer(conv1_pool, shape=[5, 5, 32, 64])
conv2_pool = max_pool_2x2(conv2)

conv3 = conv_layer(conv2_pool, shape=[5, 5, 64, 128])
conv3_pool = max_pool_2x2(conv3)

conv3_flat = tf.reshape(conv3_pool, [-1, 4*4*128])
conv3_drop = tf.nn.dropout(conv3_flat, keep_prob=keep_prob)

full_1 = tf.nn.relu(full_layer(conv3_drop, 512))
full_1_drop = tf.nn.dropout(full_1, keep_prob=keep_prob)

y_conv = full_layer(full_1_drop, 10)
# Out:
# WARNING:tensorflow:From <ipython-input-9-d4cdc2779984>:16: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# hyper parameter
learning_rate = 1e-3
epochs = 50 

# 손실함수
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=y_conv, labels=y_))
train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())

  start_time = datetime.now()

  # 학습
  for i in range(epochs):

    total_batch = int(len(train_x)/MINIBATCH_SIZE)    # 50,000 / 50

    for step in range(total_batch+1):
      batch_xs, batch_ys = sess.run(next_batch)
      loss_val, _ = sess.run([loss, train_step], feed_dict={x: batch_xs['image'], y_: batch_ys, keep_prob: 0.5})
          
      if step % 500 == 0:
        print('epochs = ', i, ', step = ', step, ', loss_val = ', loss_val)
  
  end_time = datetime.now()

  print('Elapsed Time => ', end_time-start_time)

  X = test_x.reshape([10, 1000, 32, 32, 3])
  Y = test_y.reshape([10, 1000, 10])

  test_accuracy = np.mean([sess.run(accuracy, feed_dict={x: X[i], y_: Y[i], keep_prob: 1.0}) for i in range(10)])
  print("Accuracy = ", test_accuracy)
# Out:
# epochs =  0 , step =  0 , loss_val =  35.624386
# epochs =  0 , step =  500 , loss_val =  1.9553088
# epochs =  0 , step =  1000 , loss_val =  1.6410685
# epochs =  1 , step =  0 , loss_val =  1.5917166
# epochs =  1 , step =  500 , loss_val =  1.3029006
# epochs =  1 , step =  1000 , loss_val =  1.5640259
# epochs =  2 , step =  0 , loss_val =  1.6319532
# epochs =  2 , step =  500 , loss_val =  1.1284769
# epochs =  2 , step =  1000 , loss_val =  1.3874838
# epochs =  3 , step =  0 , loss_val =  1.2205163
# epochs =  3 , step =  500 , loss_val =  1.2211626
# epochs =  3 , step =  1000 , loss_val =  1.0650125
# epochs =  4 , step =  0 , loss_val =  1.5036165
# epochs =  4 , step =  500 , loss_val =  0.8344557
# epochs =  4 , step =  1000 , loss_val =  0.6536321
# epochs =  5 , step =  0 , loss_val =  1.0082927
# epochs =  5 , step =  500 , loss_val =  0.7584866
# epochs =  5 , step =  1000 , loss_val =  1.1998523
# epochs =  6 , step =  0 , loss_val =  1.1367303
# epochs =  6 , step =  500 , loss_val =  1.0794548
# epochs =  6 , step =  1000 , loss_val =  0.7909008
# epochs =  7 , step =  0 , loss_val =  0.84467936
# epochs =  7 , step =  500 , loss_val =  1.1309918
# epochs =  7 , step =  1000 , loss_val =  1.046438
# epochs =  8 , step =  0 , loss_val =  0.67423815
# epochs =  8 , step =  500 , loss_val =  0.836998
# epochs =  8 , step =  1000 , loss_val =  0.7346297
# epochs =  9 , step =  0 , loss_val =  1.0064882
# epochs =  9 , step =  500 , loss_val =  0.6742354
# epochs =  9 , step =  1000 , loss_val =  0.7393572
# epochs =  10 , step =  0 , loss_val =  0.72002625
# epochs =  10 , step =  500 , loss_val =  0.71321374
# epochs =  10 , step =  1000 , loss_val =  0.81761926
# epochs =  11 , step =  0 , loss_val =  0.44957322
# epochs =  11 , step =  500 , loss_val =  1.266396
# epochs =  11 , step =  1000 , loss_val =  0.61475927
# epochs =  12 , step =  0 , loss_val =  0.6250887
# epochs =  12 , step =  500 , loss_val =  0.7718061
# epochs =  12 , step =  1000 , loss_val =  0.6181483
# epochs =  13 , step =  0 , loss_val =  0.65948486
# epochs =  13 , step =  500 , loss_val =  1.179022
# epochs =  13 , step =  1000 , loss_val =  0.66139066
# epochs =  14 , step =  0 , loss_val =  0.50659704
# epochs =  14 , step =  500 , loss_val =  0.8856095
# epochs =  14 , step =  1000 , loss_val =  0.91760653
# epochs =  15 , step =  0 , loss_val =  0.4915556
# epochs =  15 , step =  500 , loss_val =  0.30454886
# epochs =  15 , step =  1000 , loss_val =  0.4832486
# epochs =  16 , step =  0 , loss_val =  0.62688714
# epochs =  16 , step =  500 , loss_val =  0.61097604
# epochs =  16 , step =  1000 , loss_val =  0.65195113
# epochs =  17 , step =  0 , loss_val =  0.6567724
# epochs =  17 , step =  500 , loss_val =  0.4384233
# epochs =  17 , step =  1000 , loss_val =  0.6266368
# epochs =  18 , step =  0 , loss_val =  0.3940334
# epochs =  18 , step =  500 , loss_val =  0.58577895
# epochs =  18 , step =  1000 , loss_val =  0.50255847
# epochs =  19 , step =  0 , loss_val =  0.54387456
# epochs =  19 , step =  500 , loss_val =  0.47667736
# epochs =  19 , step =  1000 , loss_val =  0.577965
# epochs =  20 , step =  0 , loss_val =  0.4380702
# epochs =  20 , step =  500 , loss_val =  0.69041574
# epochs =  20 , step =  1000 , loss_val =  0.31099322
# epochs =  21 , step =  0 , loss_val =  0.4108486
# epochs =  21 , step =  500 , loss_val =  0.54044294
# epochs =  21 , step =  1000 , loss_val =  0.36659822
# epochs =  22 , step =  0 , loss_val =  1.0305198
# epochs =  22 , step =  500 , loss_val =  0.4820659
# epochs =  22 , step =  1000 , loss_val =  0.7547209
# epochs =  23 , step =  0 , loss_val =  0.4493827
# epochs =  23 , step =  500 , loss_val =  0.55458903
# epochs =  23 , step =  1000 , loss_val =  0.61086404
# epochs =  24 , step =  0 , loss_val =  0.32179055
# epochs =  24 , step =  500 , loss_val =  0.55685586
# epochs =  24 , step =  1000 , loss_val =  0.36044982
# epochs =  25 , step =  0 , loss_val =  0.45116004
# epochs =  25 , step =  500 , loss_val =  0.5427108
# epochs =  25 , step =  1000 , loss_val =  0.3767488
# epochs =  26 , step =  0 , loss_val =  0.5021643
# epochs =  26 , step =  500 , loss_val =  0.3520797
# epochs =  26 , step =  1000 , loss_val =  0.5507117
# epochs =  27 , step =  0 , loss_val =  0.22643048
# epochs =  27 , step =  500 , loss_val =  0.36822766
# epochs =  27 , step =  1000 , loss_val =  0.36625993
# epochs =  28 , step =  0 , loss_val =  0.29358956
# epochs =  28 , step =  500 , loss_val =  0.2594253
# epochs =  28 , step =  1000 , loss_val =  0.5472796
# epochs =  29 , step =  0 , loss_val =  0.28440583
# epochs =  29 , step =  500 , loss_val =  0.5062619
# epochs =  29 , step =  1000 , loss_val =  0.4793628
# epochs =  30 , step =  0 , loss_val =  0.34766853
# epochs =  30 , step =  500 , loss_val =  0.52971864
# epochs =  30 , step =  1000 , loss_val =  0.50234073
# epochs =  31 , step =  0 , loss_val =  0.31193405
# epochs =  31 , step =  500 , loss_val =  0.8422288
# epochs =  31 , step =  1000 , loss_val =  0.49802184
# epochs =  32 , step =  0 , loss_val =  0.3731937
# epochs =  32 , step =  500 , loss_val =  0.64645445
# epochs =  32 , step =  1000 , loss_val =  0.40423584
# epochs =  33 , step =  0 , loss_val =  0.48527527
# epochs =  33 , step =  500 , loss_val =  0.4131723
# epochs =  33 , step =  1000 , loss_val =  0.61060584
# epochs =  34 , step =  0 , loss_val =  0.24575129
# epochs =  34 , step =  500 , loss_val =  0.6870633
# epochs =  34 , step =  1000 , loss_val =  0.54358274
# epochs =  35 , step =  0 , loss_val =  0.32296368
# epochs =  35 , step =  500 , loss_val =  0.49940118
# epochs =  35 , step =  1000 , loss_val =  0.3266625
# epochs =  36 , step =  0 , loss_val =  0.37716255
# epochs =  36 , step =  500 , loss_val =  0.2739082
# epochs =  36 , step =  1000 , loss_val =  0.21202508
# epochs =  37 , step =  0 , loss_val =  0.3097546
# epochs =  37 , step =  500 , loss_val =  0.41592094
# epochs =  37 , step =  1000 , loss_val =  0.25758705
# epochs =  38 , step =  0 , loss_val =  0.35358796
# epochs =  38 , step =  500 , loss_val =  0.17941824
# epochs =  38 , step =  1000 , loss_val =  0.5104239
# epochs =  39 , step =  0 , loss_val =  0.4624473
# epochs =  39 , step =  500 , loss_val =  0.451634
# epochs =  39 , step =  1000 , loss_val =  0.29599732
# epochs =  40 , step =  0 , loss_val =  0.29633626
# epochs =  40 , step =  500 , loss_val =  0.35284224
# epochs =  40 , step =  1000 , loss_val =  0.18072537
# epochs =  41 , step =  0 , loss_val =  0.38467118
# epochs =  41 , step =  500 , loss_val =  0.47458237
# epochs =  41 , step =  1000 , loss_val =  0.26195475
# epochs =  42 , step =  0 , loss_val =  0.20264299
# epochs =  42 , step =  500 , loss_val =  0.3810325
# epochs =  42 , step =  1000 , loss_val =  0.41651544
# epochs =  43 , step =  0 , loss_val =  0.32461873
# epochs =  43 , step =  500 , loss_val =  0.1922372
# epochs =  43 , step =  1000 , loss_val =  0.27494088
# epochs =  44 , step =  0 , loss_val =  0.4394975
# epochs =  44 , step =  500 , loss_val =  0.25361946
# epochs =  44 , step =  1000 , loss_val =  0.39888337
# epochs =  45 , step =  0 , loss_val =  0.5072575
# epochs =  45 , step =  500 , loss_val =  0.27637127
# epochs =  45 , step =  1000 , loss_val =  0.27668226
# epochs =  46 , step =  0 , loss_val =  0.30578697
# epochs =  46 , step =  500 , loss_val =  0.26896706
# epochs =  46 , step =  1000 , loss_val =  0.27782154
# epochs =  47 , step =  0 , loss_val =  0.36705688
# epochs =  47 , step =  500 , loss_val =  0.35029218
# epochs =  47 , step =  1000 , loss_val =  0.3420282
# epochs =  48 , step =  0 , loss_val =  0.25766572
# epochs =  48 , step =  500 , loss_val =  0.28168857
# epochs =  48 , step =  1000 , loss_val =  0.41136578
# epochs =  49 , step =  0 , loss_val =  0.21621618
# epochs =  49 , step =  500 , loss_val =  0.29170486
# epochs =  49 , step =  1000 , loss_val =  0.16476436
# Elapsed Time =>  0:07:41.498759
# Accuracy =  0.76739997
