# %%
import numpy as np
import tensorflow as tf
from datetime import datetime
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# helper 함수
def weight_variables(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# convolution layer
def conv_layer(input_, shape):
  W = weight_variables(shape)
  b = bias_variable([shape[3]])
  return tf.nn.relu(conv2d(input_, W) + b)

# fully-connected layer
def full_layer(input_, size):
  in_size = int(input_.get_shape()[1])
  W = weight_variables([in_size, size])
  b = bias_variable([size])
  return tf.matmul(input_, W) + b

# %%
# cifar10 데이터 불러오기
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()

# %%
def cifar10_load():

  (train_x, train_y), (test_x, test_y) = tf.keras.datasets.cifar10.load_data()

  # Train - Image
  train_x = train_x.astype('float32') / 255

  # Train - Label(OneHot)
  train_y = tf.keras.utils.to_categorical(train_y, num_classes=10)

  # Test - Image
  test_x = test_x.astype('float32') / 255
      
  # Test - Label(OneHot)
  test_y = tf.keras.utils.to_categorical(test_y, num_classes=10)
      
  return (train_x, train_y), (test_x, test_y)

# %%
MINIBATCH_SIZE = 50

(train_x, train_y), (test_x, test_y) = cifar10_load()

dataset = tf.data.Dataset.from_tensor_slices(({"image": train_x}, train_y))

dataset = dataset.shuffle(100000).repeat().batch(MINIBATCH_SIZE)

iterator = dataset.make_one_shot_iterator()

next_batch = iterator.get_next()
# Out:
# WARNING:tensorflow:From <ipython-input-5-81f0afd831c2>:9: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.

# %%
print("Number of train images: {}".format(len(train_x)))
print("Number of train labels: {}".format(len(train_y)))
print("Number of test images: {}".format(len(test_x)))
print("Number of test labels: {}".format(len(test_y)))
# Out:
# Number of train images: 50000
# Number of train labels: 50000
# Number of test images: 10000
# Number of test labels: 10000

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

matplotlib.rc('font', family='NanumGothic')


def display_cifar(images, size):
  
  n = len(images)
  plt.figure()
  plt.gca().set_axis_off()
  im = np.vstack([np.hstack([images[np.random.choice(n)] for i in range(size)]) for i in range(size)])
  plt.imshow(im)
  plt.show()
      
figsize(15, 7)
display_cifar(train_x, 10)

# %%
(train_x, train_y), (test_x, test_y) = cifar10_load()

dataset = tf.data.Dataset.from_tensor_slices(({"image": train_x}, train_y))
dataset = dataset.shuffle(100000).repeat().batch(MINIBATCH_SIZE)
iterator = dataset.make_one_shot_iterator()
next_batch = iterator.get_next()

# %%
# CNN 모델링
x = tf.placeholder(tf.float32, shape=[None, 32, 32, 3])
y_ = tf.placeholder(tf.float32, shape=[None, 10])
keep_prob = tf.placeholder(tf.float32)

conv1 = conv_layer(x, shape=[5, 5, 3, 32])
conv1_pool = max_pool_2x2(conv1)

conv2 = conv_layer(conv1_pool, shape=[5, 5, 32, 64])
conv2_pool = max_pool_2x2(conv2)

conv3 = conv_layer(conv2_pool, shape=[5, 5, 64, 128])
conv3_pool = max_pool_2x2(conv3)

conv3_flat = tf.reshape(conv3_pool, [-1, 4*4*128])
conv3_drop = tf.nn.dropout(conv3_flat, keep_prob=keep_prob)

full_1 = tf.nn.relu(full_layer(conv3_drop, 512))
full_1_drop = tf.nn.dropout(full_1, keep_prob=keep_prob)

y_conv = full_layer(full_1_drop, 10)
# Out:
# WARNING:tensorflow:From <ipython-input-9-82bf524bbce6>:15: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# hyper parameter
learning_rate = 1e-3
epochs = 50 

# 손실함수
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=y_conv, labels=y_))
train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())

  start_time = datetime.now()

  # 학습
  for i in range(epochs):

    total_batch = int(len(train_x)/MINIBATCH_SIZE)    # 50,000 / 50

    for step in range(total_batch+1):
      batch_xs, batch_ys = sess.run(next_batch)
      loss_val, _ = sess.run([loss, train_step], feed_dict={x: batch_xs['image'], y_: batch_ys, keep_prob: 0.5})
          
      if step % 500 == 0:
        print('epochs = ', i, ', step = ', step, ', loss_val = ', loss_val)
  
  end_time = datetime.now()

  print('Elapsed Time => ', end_time-start_time)

  X = test_x.reshape([10, 1000, 32, 32, 3])
  Y = test_y.reshape([10, 1000, 10])

  test_accuracy = np.mean([sess.run(accuracy, feed_dict={x: X[i], y_: Y[i], keep_prob: 1.0}) for i in range(10)])
  print("Accuracy = ", test_accuracy)
# Out:
# epochs =  0 , step =  0 , loss_val =  27.939625
# epochs =  0 , step =  500 , loss_val =  1.8423758
# epochs =  0 , step =  1000 , loss_val =  1.7237005
# epochs =  1 , step =  0 , loss_val =  1.6575916
# epochs =  1 , step =  500 , loss_val =  1.2808063
# epochs =  1 , step =  1000 , loss_val =  1.3531487
# epochs =  2 , step =  0 , loss_val =  1.2598665
# epochs =  2 , step =  500 , loss_val =  0.99444765
# epochs =  2 , step =  1000 , loss_val =  1.3096656
# epochs =  3 , step =  0 , loss_val =  1.1268655
# epochs =  3 , step =  500 , loss_val =  0.90342635
# epochs =  3 , step =  1000 , loss_val =  1.1876764
# epochs =  4 , step =  0 , loss_val =  1.2738336
# epochs =  4 , step =  500 , loss_val =  1.0141213
# epochs =  4 , step =  1000 , loss_val =  1.0781021
# epochs =  5 , step =  0 , loss_val =  1.1132294
# epochs =  5 , step =  500 , loss_val =  0.94463104
# epochs =  5 , step =  1000 , loss_val =  0.834207
# epochs =  6 , step =  0 , loss_val =  0.8662077
# epochs =  6 , step =  500 , loss_val =  0.8091675
# epochs =  6 , step =  1000 , loss_val =  0.96283567
# epochs =  7 , step =  0 , loss_val =  0.6560662
# epochs =  7 , step =  500 , loss_val =  0.8509128
# epochs =  7 , step =  1000 , loss_val =  0.9188913
# epochs =  8 , step =  0 , loss_val =  0.82994723
# epochs =  8 , step =  500 , loss_val =  1.1552373
# epochs =  8 , step =  1000 , loss_val =  0.58420676
# epochs =  9 , step =  0 , loss_val =  0.92383593
# epochs =  9 , step =  500 , loss_val =  1.2014982
# epochs =  9 , step =  1000 , loss_val =  0.8183861
# epochs =  10 , step =  0 , loss_val =  0.8414663
# epochs =  10 , step =  500 , loss_val =  0.83345675
# epochs =  10 , step =  1000 , loss_val =  0.6935741
# epochs =  11 , step =  0 , loss_val =  0.35723865
# epochs =  11 , step =  500 , loss_val =  0.5186324
# epochs =  11 , step =  1000 , loss_val =  0.6152583
# epochs =  12 , step =  0 , loss_val =  0.59963477
# epochs =  12 , step =  500 , loss_val =  0.6273859
# epochs =  12 , step =  1000 , loss_val =  0.75368637
# epochs =  13 , step =  0 , loss_val =  0.5634585
# epochs =  13 , step =  500 , loss_val =  0.5647158
# epochs =  13 , step =  1000 , loss_val =  0.7068204
# epochs =  14 , step =  0 , loss_val =  0.5607148
# epochs =  14 , step =  500 , loss_val =  0.5335425
# epochs =  14 , step =  1000 , loss_val =  0.594133
# epochs =  15 , step =  0 , loss_val =  0.6587794
# epochs =  15 , step =  500 , loss_val =  0.5772947
# epochs =  15 , step =  1000 , loss_val =  0.56282043
# epochs =  16 , step =  0 , loss_val =  0.6817793
# epochs =  16 , step =  500 , loss_val =  0.7056534
# epochs =  16 , step =  1000 , loss_val =  0.6626122
# epochs =  17 , step =  0 , loss_val =  0.50853384
# epochs =  17 , step =  500 , loss_val =  0.73971575
# epochs =  17 , step =  1000 , loss_val =  0.55251294
# epochs =  18 , step =  0 , loss_val =  0.573033
# epochs =  18 , step =  500 , loss_val =  0.70823324
# epochs =  18 , step =  1000 , loss_val =  0.4769051
# epochs =  19 , step =  0 , loss_val =  0.4099733
# epochs =  19 , step =  500 , loss_val =  0.47737274
# epochs =  19 , step =  1000 , loss_val =  0.41097224
# epochs =  20 , step =  0 , loss_val =  0.5778
# epochs =  20 , step =  500 , loss_val =  0.3817342
# epochs =  20 , step =  1000 , loss_val =  0.82713544
# epochs =  21 , step =  0 , loss_val =  0.22183323
# epochs =  21 , step =  500 , loss_val =  0.65029943
# epochs =  21 , step =  1000 , loss_val =  0.24985163
# epochs =  22 , step =  0 , loss_val =  0.49216858
# epochs =  22 , step =  500 , loss_val =  0.4232375
# epochs =  22 , step =  1000 , loss_val =  0.5386227
# epochs =  23 , step =  0 , loss_val =  0.41805485
# epochs =  23 , step =  500 , loss_val =  0.5018911
# epochs =  23 , step =  1000 , loss_val =  0.4248601
# epochs =  24 , step =  0 , loss_val =  0.48902202
# epochs =  24 , step =  500 , loss_val =  0.27145648
# epochs =  24 , step =  1000 , loss_val =  0.2941694
# epochs =  25 , step =  0 , loss_val =  0.4263374
# epochs =  25 , step =  500 , loss_val =  0.28863707
# epochs =  25 , step =  1000 , loss_val =  0.51250017
# epochs =  26 , step =  0 , loss_val =  0.3191136
# epochs =  26 , step =  500 , loss_val =  0.698159
# epochs =  26 , step =  1000 , loss_val =  0.47620532
# epochs =  27 , step =  0 , loss_val =  0.4319752
# epochs =  27 , step =  500 , loss_val =  0.81281763
# epochs =  27 , step =  1000 , loss_val =  0.44405055
# epochs =  28 , step =  0 , loss_val =  0.224807
# epochs =  28 , step =  500 , loss_val =  0.4651561
# epochs =  28 , step =  1000 , loss_val =  0.31459144
# epochs =  29 , step =  0 , loss_val =  0.47115394
# epochs =  29 , step =  500 , loss_val =  0.493363
# epochs =  29 , step =  1000 , loss_val =  0.33283198
# epochs =  30 , step =  0 , loss_val =  0.38674378
# epochs =  30 , step =  500 , loss_val =  0.5956717
# epochs =  30 , step =  1000 , loss_val =  0.3097815
# epochs =  31 , step =  0 , loss_val =  0.48929024
# epochs =  31 , step =  500 , loss_val =  0.3882213
# epochs =  31 , step =  1000 , loss_val =  0.4728141
# epochs =  32 , step =  0 , loss_val =  0.39219198
# epochs =  32 , step =  500 , loss_val =  0.36340773
# epochs =  32 , step =  1000 , loss_val =  0.7612579
# epochs =  33 , step =  0 , loss_val =  0.51369524
# epochs =  33 , step =  500 , loss_val =  0.32430112
# epochs =  33 , step =  1000 , loss_val =  0.3891996
# epochs =  34 , step =  0 , loss_val =  0.32746795
# epochs =  34 , step =  500 , loss_val =  0.73358566
# epochs =  34 , step =  1000 , loss_val =  0.40262735
# epochs =  35 , step =  0 , loss_val =  0.24512705
# epochs =  35 , step =  500 , loss_val =  0.42671233
# epochs =  35 , step =  1000 , loss_val =  0.3724563
# epochs =  36 , step =  0 , loss_val =  0.24801831
# epochs =  36 , step =  500 , loss_val =  0.17846334
# epochs =  36 , step =  1000 , loss_val =  0.07650633
# epochs =  37 , step =  0 , loss_val =  0.27954784
# epochs =  37 , step =  500 , loss_val =  0.32517353
# epochs =  37 , step =  1000 , loss_val =  0.30094025
# epochs =  38 , step =  0 , loss_val =  0.40953246
# epochs =  38 , step =  500 , loss_val =  0.40971705
# epochs =  38 , step =  1000 , loss_val =  0.5208588
# epochs =  39 , step =  0 , loss_val =  0.2134045
# epochs =  39 , step =  500 , loss_val =  0.75934654
# epochs =  39 , step =  1000 , loss_val =  0.32051927
# epochs =  40 , step =  0 , loss_val =  0.22395797
# epochs =  40 , step =  500 , loss_val =  0.2562861
# epochs =  40 , step =  1000 , loss_val =  0.29061556
# epochs =  41 , step =  0 , loss_val =  0.45307913
# epochs =  41 , step =  500 , loss_val =  0.47986707
# epochs =  41 , step =  1000 , loss_val =  0.47576156
# epochs =  42 , step =  0 , loss_val =  0.32208157
# epochs =  42 , step =  500 , loss_val =  0.6762674
# epochs =  42 , step =  1000 , loss_val =  0.40969408
# epochs =  43 , step =  0 , loss_val =  0.24183315
# epochs =  43 , step =  500 , loss_val =  0.49439755
# epochs =  43 , step =  1000 , loss_val =  0.15715
# epochs =  44 , step =  0 , loss_val =  0.5113491
# epochs =  44 , step =  500 , loss_val =  0.7736688
# epochs =  44 , step =  1000 , loss_val =  0.44362503
# epochs =  45 , step =  0 , loss_val =  0.4049392
# epochs =  45 , step =  500 , loss_val =  0.4087954
# epochs =  45 , step =  1000 , loss_val =  0.4798904
# epochs =  46 , step =  0 , loss_val =  0.27370837
# epochs =  46 , step =  500 , loss_val =  0.40244448
# epochs =  46 , step =  1000 , loss_val =  0.37946147
# epochs =  47 , step =  0 , loss_val =  0.17788662
# epochs =  47 , step =  500 , loss_val =  0.34288082
# epochs =  47 , step =  1000 , loss_val =  0.18412691
# epochs =  48 , step =  0 , loss_val =  0.3291728
# epochs =  48 , step =  500 , loss_val =  0.52745074
# epochs =  48 , step =  1000 , loss_val =  0.40276352
# epochs =  49 , step =  0 , loss_val =  0.54909927
# epochs =  49 , step =  500 , loss_val =  0.57706404
# epochs =  49 , step =  1000 , loss_val =  0.24956559
# Elapsed Time =>  0:04:49.524633
# Accuracy =  0.75420004
