# %% [markdown]
# ## Feed Forward 이해 및 계산 연습

# %%
import numpy as np


# 수치미분 함수
def numerical_derivative(f, x):
    delta_x = 1e-4 # 0.0001
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    
    while not it.finished:
        idx = it.multi_index        
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + delta_x
        fx1 = f(x) # f(x+delta_x)
        
        x[idx] = tmp_val - delta_x 
        fx2 = f(x) # f(x-delta_x)
        grad[idx] = (fx1 - fx2) / (2*delta_x)
        
        x[idx] = tmp_val 
        it.iternext()   
        
    return grad

# 활성화함수 sigmoid
def sigmoid(x):
    
    return 1 / (1 + np.exp(-x))

# %%
input_data1 = np.array([1, 2])    # 입력데이터
target_data1 = np.array([1])      # 정답데이터

# %% [markdown]
# #### 신경망 아키텍처 그려볼것

# %%
input_nodes = 2    # 입력노드
hidden_nodes = 3   # 은닉노드
output_nodes = 1   # 출력노드

# %% [markdown]
# #### 신경망 아키텍처 그려볼것

# %%
W2 = np.random.rand(input_nodes, hidden_nodes)
b2 = np.random.rand(hidden_nodes)

W3 = np.random.rand(hidden_nodes, output_nodes)
b3 = np.random.rand(output_nodes)

print("W2 = ", W2, ", W2.shape = ", W2.shape)
print("b2 = ", b2, ", b2.shape = ", b2.shape)
print("W3 = ", W3, ", W3.shape = ", W3.shape)
print("b3 = ", b3, ", b3.shape = ", b3.shape)
# Out:
# W2 =  [[0.54826522 0.67504707 0.60715071]
#  [0.44302399 0.33888802 0.95859415]] , W2.shape =  (2, 3)
# b2 =  [0.50864015 0.18775934 0.09395645] , b2.shape =  (3,)
# W3 =  [[0.5811825 ]
#  [0.28714709]
#  [0.02916474]] , W3.shape =  (3, 1)
# b3 =  [0.77397842] , b3.shape =  (1,)

# %% [markdown]
# #### Z2, A2, Z3, y(=A3), loss 값을 신경망 아키텍처에서 설명해볼것

# %%
def feed_forward(xdata):
    
    delta = 1e-7
    
    Z2 = np.dot(xdata, W2) + b2
    
    print("[feed_forward function]")
    
    print("Z2 = ", Z2)
    
    A2 = sigmoid(Z2)
    
    print("A2 = ", A2)
    
    Z3 = np.dot(A2, W3) + b3
    
    print("Z3 = ", Z3)
    
    y = A3 = sigmoid(Z3)
    
    print("y = ", y, ", A3 = ", A3)
    
    loss = -np.sum( target_data1*np.log(y + delta) + (1-target_data1)*np.log((1 - y)+delta ) )
    
    print('current loss val = ', loss)
    
    print("[feed_forward function]")
        
    return loss

# %%
loss_val = feed_forward(input_data1)
# Out:
# [feed_forward function]
# Z2 =  [1.94295336 1.54058245 2.61829545]
# A2 =  [0.87467624 0.82354938 0.9320298 ]
# Z3 =  [1.54598716]
# y =  [0.8243334] , A3 =  [0.8243334]
# current loss val =  0.1931801009987259
# [feed_forward function]

# %% [markdown]
# #### 수치미분을 이용하여 가중치 W2, W3, 바이어스 b2, b3 업데이트

# %%
learning_rate = 1e-1

f = lambda x : feed_forward(input_data1)
print('\n=================================================')
print('initial W2 = ', W2)
print('initial b2 = ', b2)
print('initial W3 = ', W3)
print('initial b3 = ', b3)
print('=================================================\n')

W2 -= learning_rate * numerical_derivative( f, W2 )
b2 -= learning_rate * numerical_derivative( f, b2 )

W3 -= learning_rate * numerical_derivative( f, W3 )
b3 -= learning_rate * numerical_derivative( f, b3 )

print('\n=================================================')
print('updated W2 = ', W2)
print('updated b2 = ', b2)
print('updated W3 = ', W3)
print('updated b3 = ', b3)
print('=================================================\n')
# Out:
# =================================================
# initial W2 =  [[0.54826522 0.67504707 0.60715071]
#  [0.44302399 0.33888802 0.95859415]]
# initial b2 =  [0.50864015 0.18775934 0.09395645]
# initial W3 =  [[0.5811825 ]
#  [0.28714709]
#  [0.02916474]]
# initial b3 =  [0.77397842]
# =================================================
#
# [feed_forward function]
# Z2 =  [1.94305336 1.54058245 2.61829545]
# A2 =  [0.8746872  0.82354938 0.9320298 ]
# Z3 =  [1.54599353]
# y =  [0.82433432] , A3 =  [0.82433432]
# current loss val =  0.19317898190875113
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94285336 1.54058245 2.61829545]
# A2 =  [0.87466528 0.82354938 0.9320298 ]
# Z3 =  [1.54598079]
# y =  [0.82433247] , A3 =  [0.82433247]
# current loss val =  0.1931812201784406
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54068245 2.61829545]
# A2 =  [0.87467624 0.82356391 0.9320298 ]
# Z3 =  [1.54599133]
# y =  [0.824334] , A3 =  [0.824334]
# current loss val =  0.19317936801961072
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54048245 2.61829545]
# A2 =  [0.87467624 0.82353485 0.9320298 ]
# Z3 =  [1.54598299]
# y =  [0.82433279] , A3 =  [0.82433279]
# current loss val =  0.1931808340277948
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54058245 2.61839545]
# A2 =  [0.87467624 0.82354938 0.93203614]
# Z3 =  [1.54598735]
# y =  [0.82433342] , A3 =  [0.82433342]
# current loss val =  0.19318006854408926
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54058245 2.61819545]
# A2 =  [0.87467624 0.82354938 0.93202347]
# Z3 =  [1.54598698]
# y =  [0.82433337] , A3 =  [0.82433337]
# current loss val =  0.19318013345617183
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94315336 1.54058245 2.61829545]
# A2 =  [0.87469816 0.82354938 0.9320298 ]
# Z3 =  [1.5459999]
# y =  [0.82433524] , A3 =  [0.82433524]
# current loss val =  0.1931778629085112
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94275336 1.54058245 2.61829545]
# A2 =  [0.87465432 0.82354938 0.9320298 ]
# Z3 =  [1.54597442]
# y =  [0.82433155] , A3 =  [0.82433155]
# current loss val =  0.19318233944790028
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54078245 2.61829545]
# A2 =  [0.87467624 0.82357844 0.9320298 ]
# Z3 =  [1.54599551]
# y =  [0.82433461] , A3 =  [0.82433461]
# current loss val =  0.193178635090448
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54038245 2.61829545]
# A2 =  [0.87467624 0.82352032 0.9320298 ]
# Z3 =  [1.54597882]
# y =  [0.82433219] , A3 =  [0.82433219]
# current loss val =  0.19318156710681944
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54058245 2.61849545]
# A2 =  [0.87467624 0.82354938 0.93204247]
# Z3 =  [1.54598753]
# y =  [0.82433345] , A3 =  [0.82433345]
# current loss val =  0.19318003609226175
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94295336 1.54058245 2.61809545]
# A2 =  [0.87467624 0.82354938 0.93201713]
# Z3 =  [1.54598679]
# y =  [0.82433334] , A3 =  [0.82433334]
# current loss val =  0.19318016591642734
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94864904 1.54424747 2.61845773]
# A2 =  [0.87529926 0.82408133 0.93204008]
# Z3 =  [1.5465023]
# y =  [0.82440798] , A3 =  [0.82440798]
# current loss val =  0.1930896282779892
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94844904 1.54424747 2.61845773]
# A2 =  [0.87527743 0.82408133 0.93204008]
# Z3 =  [1.54648961]
# y =  [0.82440614] , A3 =  [0.82440614]
# current loss val =  0.19309185623965316
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94854904 1.54434747 2.61845773]
# A2 =  [0.87528834 0.82409583 0.93204008]
# Z3 =  [1.54650012]
# y =  [0.82440766] , A3 =  [0.82440766]
# current loss val =  0.1930900112793859
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94854904 1.54414747 2.61845773]
# A2 =  [0.87528834 0.82406684 0.93204008]
# Z3 =  [1.54649179]
# y =  [0.82440646] , A3 =  [0.82440646]
# current loss val =  0.1930914731987039
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94854904 1.54424747 2.61855773]
# A2 =  [0.87528834 0.82408133 0.93204642]
# Z3 =  [1.54649614]
# y =  [0.82440709] , A3 =  [0.82440709]
# current loss val =  0.19309070977762333
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94854904 1.54424747 2.61835773]
# A2 =  [0.87528834 0.82408133 0.93203375]
# Z3 =  [1.54649577]
# y =  [0.82440704] , A3 =  [0.82440704]
# current loss val =  0.19309077465338775
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.54668462]
# y =  [0.82443437] , A3 =  [0.82443437]
# current loss val =  0.19305761659027318
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.54650954]
# y =  [0.82440903] , A3 =  [0.82440903]
# current loss val =  0.1930883571826376
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.5466795]
# y =  [0.82443363] , A3 =  [0.82443363]
# current loss val =  0.1930585158851257
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.54651466]
# y =  [0.82440977] , A3 =  [0.82440977]
# current loss val =  0.19308745776176872
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.54669028]
# y =  [0.82443519] , A3 =  [0.82443519]
# current loss val =  0.19305662232515697
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.54650387]
# y =  [0.82440821] , A3 =  [0.82440821]
# current loss val =  0.1930893515959205
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.58733168]
# y =  [0.83024036] , A3 =  [0.83024036]
# current loss val =  0.18603991205639125
# [feed_forward function]
# [feed_forward function]
# Z2 =  [1.94966302 1.54497843 2.61849017]
# A2 =  [0.87540989 0.82418728 0.93204214]
# Z3 =  [1.58713168]
# y =  [0.83021217] , A3 =  [0.83021217]
# current loss val =  0.18607386679970825
# [feed_forward function]
#
# =================================================
# updated W2 =  [[0.54938436 0.67578007 0.60718316]
#  [0.44526226 0.34035403 0.95865906]]
# updated b2 =  [0.50975413 0.1884903  0.09398889]
# updated W3 =  [[0.5965528 ]
#  [0.30161803]
#  [0.04552937]]
# updated b3 =  [0.7909558]
# =================================================
