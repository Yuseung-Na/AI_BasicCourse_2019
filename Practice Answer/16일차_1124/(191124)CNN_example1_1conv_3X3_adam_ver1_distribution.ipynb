# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-1-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/ai0/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/ai0/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/ai0/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/ai0/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/ai0/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 30            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28X28X1 (black/white)


T = tf.placeholder(tf.float32, [None, 10])

# %%
# 1번째 컨볼루션 층, 3X3X32 필터
W2 = tf.Variable(tf.random_normal([3, 3, 1, 32], stddev=0.01))  
#W2 = tf.Variable(tf.random_normal([3, 3, 1, 32]))  
#b2 = tf.Variable(tf.constant(0.1, shape=[32]))  
b2 = tf.Variable(tf.random_normal([32])) 

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 14X14 크기를 가진 32개의 activation map을 flatten 시킴
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*32])

# %%
# 출력층
W3 = tf.Variable(tf.random_normal([14*14*32, 10], stddev=0.01))
#W3 = tf.Variable(tf.random_normal([14*14*32, 10]))
b3 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z3, 즉 softmax 에 들어가는 입력 값
Z3 = logits = tf.matmul(A2_flat, W3) + b3    # 선형회귀 값 Z3

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z3, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A3, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# %%
with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 50 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val = sess.run([accuracy], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
# Out:
# epochs =  0 , step =  0 , loss_val =  2.9379182
# epochs =  0 , step =  100 , loss_val =  1.4812291
# epochs =  0 , step =  200 , loss_val =  0.46807098
# epochs =  0 , step =  300 , loss_val =  0.5311588
# epochs =  0 , step =  400 , loss_val =  0.32696924
# epochs =  0 , step =  500 , loss_val =  0.52073485
# epochs =  1 , step =  0 , loss_val =  0.27147615
# epochs =  1 , step =  100 , loss_val =  0.43422386
# epochs =  1 , step =  200 , loss_val =  0.35191974
# epochs =  1 , step =  300 , loss_val =  0.19076622
# epochs =  1 , step =  400 , loss_val =  0.2539729
# epochs =  1 , step =  500 , loss_val =  0.2215728
# epochs =  2 , step =  0 , loss_val =  0.40594596
# epochs =  2 , step =  100 , loss_val =  0.2426313
# epochs =  2 , step =  200 , loss_val =  0.23509371
# epochs =  2 , step =  300 , loss_val =  0.2739627
# epochs =  2 , step =  400 , loss_val =  0.2228215
# epochs =  2 , step =  500 , loss_val =  0.28155863
# epochs =  3 , step =  0 , loss_val =  0.29576272
# epochs =  3 , step =  100 , loss_val =  0.3545576
# epochs =  3 , step =  200 , loss_val =  0.18554795
# epochs =  3 , step =  300 , loss_val =  0.29066744
# epochs =  3 , step =  400 , loss_val =  0.17992336
# epochs =  3 , step =  500 , loss_val =  0.22909185
# epochs =  4 , step =  0 , loss_val =  0.15893127
# epochs =  4 , step =  100 , loss_val =  0.14117853
# epochs =  4 , step =  200 , loss_val =  0.08047039
# epochs =  4 , step =  300 , loss_val =  0.24938644
# epochs =  4 , step =  400 , loss_val =  0.22221838
# epochs =  4 , step =  500 , loss_val =  0.21943738
# epochs =  5 , step =  0 , loss_val =  0.10431001
# epochs =  5 , step =  100 , loss_val =  0.07826204
# epochs =  5 , step =  200 , loss_val =  0.11071873
# epochs =  5 , step =  300 , loss_val =  0.19469383
# epochs =  5 , step =  400 , loss_val =  0.27082324
# epochs =  5 , step =  500 , loss_val =  0.07673072
# epochs =  6 , step =  0 , loss_val =  0.1946414
# epochs =  6 , step =  100 , loss_val =  0.14550337
# epochs =  6 , step =  200 , loss_val =  0.18481688
# epochs =  6 , step =  300 , loss_val =  0.060250502
# epochs =  6 , step =  400 , loss_val =  0.0916871
# epochs =  6 , step =  500 , loss_val =  0.1396061
# epochs =  7 , step =  0 , loss_val =  0.080482714
# epochs =  7 , step =  100 , loss_val =  0.17375015
# epochs =  7 , step =  200 , loss_val =  0.064997874
# epochs =  7 , step =  300 , loss_val =  0.09082686
# epochs =  7 , step =  400 , loss_val =  0.07006625
# epochs =  7 , step =  500 , loss_val =  0.062159028
# epochs =  8 , step =  0 , loss_val =  0.083191976
# epochs =  8 , step =  100 , loss_val =  0.14658466
# epochs =  8 , step =  200 , loss_val =  0.1360687
# epochs =  8 , step =  300 , loss_val =  0.097988546
# epochs =  8 , step =  400 , loss_val =  0.09667879
# epochs =  8 , step =  500 , loss_val =  0.096664876
# epochs =  9 , step =  0 , loss_val =  0.050494533
# epochs =  9 , step =  100 , loss_val =  0.034006707
# epochs =  9 , step =  200 , loss_val =  0.07654669
# epochs =  9 , step =  300 , loss_val =  0.100777246
# epochs =  9 , step =  400 , loss_val =  0.097536504
# epochs =  9 , step =  500 , loss_val =  0.24243975
# epochs =  10 , step =  0 , loss_val =  0.020612393
# epochs =  10 , step =  100 , loss_val =  0.02240715
# epochs =  10 , step =  200 , loss_val =  0.08828256
# epochs =  10 , step =  300 , loss_val =  0.03499752
# epochs =  10 , step =  400 , loss_val =  0.03865102
# epochs =  10 , step =  500 , loss_val =  0.14808235
# epochs =  11 , step =  0 , loss_val =  0.04475223
# epochs =  11 , step =  100 , loss_val =  0.09897289
# epochs =  11 , step =  200 , loss_val =  0.022912057
# epochs =  11 , step =  300 , loss_val =  0.081259534
# epochs =  11 , step =  400 , loss_val =  0.08501346
# epochs =  11 , step =  500 , loss_val =  0.022521978
# epochs =  12 , step =  0 , loss_val =  0.057789918
# epochs =  12 , step =  100 , loss_val =  0.15438773
# epochs =  12 , step =  200 , loss_val =  0.013016611
# epochs =  12 , step =  300 , loss_val =  0.028256567
# epochs =  12 , step =  400 , loss_val =  0.038889423
# epochs =  12 , step =  500 , loss_val =  0.015767628
# epochs =  13 , step =  0 , loss_val =  0.03687926
# epochs =  13 , step =  100 , loss_val =  0.062890574
# epochs =  13 , step =  200 , loss_val =  0.01837616
# epochs =  13 , step =  300 , loss_val =  0.080292694
# epochs =  13 , step =  400 , loss_val =  0.1043629
# epochs =  13 , step =  500 , loss_val =  0.08555664
# epochs =  14 , step =  0 , loss_val =  0.018039793
# epochs =  14 , step =  100 , loss_val =  0.06675766
# epochs =  14 , step =  200 , loss_val =  0.12530744
# epochs =  14 , step =  300 , loss_val =  0.045744527
# epochs =  14 , step =  400 , loss_val =  0.04336808
# epochs =  14 , step =  500 , loss_val =  0.08928297
# epochs =  15 , step =  0 , loss_val =  0.01731345
# epochs =  15 , step =  100 , loss_val =  0.06329655
# epochs =  15 , step =  200 , loss_val =  0.05412095
# epochs =  15 , step =  300 , loss_val =  0.035367362
# epochs =  15 , step =  400 , loss_val =  0.13011569
# epochs =  15 , step =  500 , loss_val =  0.032380957
# epochs =  16 , step =  0 , loss_val =  0.024460629
# epochs =  16 , step =  100 , loss_val =  0.013456391
# epochs =  16 , step =  200 , loss_val =  0.020398147
# epochs =  16 , step =  300 , loss_val =  0.08078844
# epochs =  16 , step =  400 , loss_val =  0.05342082
# epochs =  16 , step =  500 , loss_val =  0.021276979
# epochs =  17 , step =  0 , loss_val =  0.0542349
# epochs =  17 , step =  100 , loss_val =  0.04562225
# epochs =  17 , step =  200 , loss_val =  0.03202163
# epochs =  17 , step =  300 , loss_val =  0.0770022
# epochs =  17 , step =  400 , loss_val =  0.061480347
# epochs =  17 , step =  500 , loss_val =  0.031881303
# epochs =  18 , step =  0 , loss_val =  0.036958434
# epochs =  18 , step =  100 , loss_val =  0.027673015
# epochs =  18 , step =  200 , loss_val =  0.09641907
# epochs =  18 , step =  300 , loss_val =  0.03727502
# epochs =  18 , step =  400 , loss_val =  0.04693302
# epochs =  18 , step =  500 , loss_val =  0.0292202
# epochs =  19 , step =  0 , loss_val =  0.009396944
# epochs =  19 , step =  100 , loss_val =  0.036713924
# epochs =  19 , step =  200 , loss_val =  0.062153533
# epochs =  19 , step =  300 , loss_val =  0.016182218
# epochs =  19 , step =  400 , loss_val =  0.09084521
# epochs =  19 , step =  500 , loss_val =  0.007177825
# epochs =  20 , step =  0 , loss_val =  0.19110233
# epochs =  20 , step =  100 , loss_val =  0.043323535
# epochs =  20 , step =  200 , loss_val =  0.046992384
# epochs =  20 , step =  300 , loss_val =  0.033594467
# epochs =  20 , step =  400 , loss_val =  0.01419966
# epochs =  20 , step =  500 , loss_val =  0.041810885
# epochs =  21 , step =  0 , loss_val =  0.018215679
# epochs =  21 , step =  100 , loss_val =  0.008033924
# epochs =  21 , step =  200 , loss_val =  0.010128124
# epochs =  21 , step =  300 , loss_val =  0.029871311
# epochs =  21 , step =  400 , loss_val =  0.020783704
# epochs =  21 , step =  500 , loss_val =  0.037199408
# epochs =  22 , step =  0 , loss_val =  0.008341807
# epochs =  22 , step =  100 , loss_val =  0.055032328
# epochs =  22 , step =  200 , loss_val =  0.04933371
# epochs =  22 , step =  300 , loss_val =  0.047052395
# epochs =  22 , step =  400 , loss_val =  0.011134069
# epochs =  22 , step =  500 , loss_val =  0.00639063
# epochs =  23 , step =  0 , loss_val =  0.03475505
# epochs =  23 , step =  100 , loss_val =  0.023633463
# epochs =  23 , step =  200 , loss_val =  0.017460136
# epochs =  23 , step =  300 , loss_val =  0.049115077
# epochs =  23 , step =  400 , loss_val =  0.06327964
# epochs =  23 , step =  500 , loss_val =  0.024769725
# epochs =  24 , step =  0 , loss_val =  0.019453079
# epochs =  24 , step =  100 , loss_val =  0.096231736
# epochs =  24 , step =  200 , loss_val =  0.011922152
# epochs =  24 , step =  300 , loss_val =  0.07872077
# epochs =  24 , step =  400 , loss_val =  0.0045043286
# epochs =  24 , step =  500 , loss_val =  0.053527426
# epochs =  25 , step =  0 , loss_val =  0.031110715
# epochs =  25 , step =  100 , loss_val =  0.014562373
# epochs =  25 , step =  200 , loss_val =  0.043042064
# epochs =  25 , step =  300 , loss_val =  0.009611363
# epochs =  25 , step =  400 , loss_val =  0.031984974
# epochs =  25 , step =  500 , loss_val =  0.0049050995
# epochs =  26 , step =  0 , loss_val =  0.029726522
# epochs =  26 , step =  100 , loss_val =  0.006878302
# epochs =  26 , step =  200 , loss_val =  0.006613361
# epochs =  26 , step =  300 , loss_val =  0.0040459777
# epochs =  26 , step =  400 , loss_val =  0.0045342515
# epochs =  26 , step =  500 , loss_val =  0.041050866
# epochs =  27 , step =  0 , loss_val =  0.020123096
# epochs =  27 , step =  100 , loss_val =  0.016724287
# epochs =  27 , step =  200 , loss_val =  0.0074320054
# epochs =  27 , step =  300 , loss_val =  0.01198185
# epochs =  27 , step =  400 , loss_val =  0.03154054
# epochs =  27 , step =  500 , loss_val =  0.007860379
# epochs =  28 , step =  0 , loss_val =  0.011741464
# epochs =  28 , step =  100 , loss_val =  0.04999939
# epochs =  28 , step =  200 , loss_val =  0.069320776
# epochs =  28 , step =  300 , loss_val =  0.016000934
# epochs =  28 , step =  400 , loss_val =  0.052403312
# epochs =  28 , step =  500 , loss_val =  0.001224455
# epochs =  29 , step =  0 , loss_val =  0.010640124
